# %%
from ultralytics import YOLO
import gc

# Lista de modelos
modelos = [
    'yolov5nu.pt',
    'yolov8n.pt',
    'yolov9t.pt',
    'yolov10n.pt',
    'yolo11n.pt'
]

# Ruta al archivo de configuración del dataset
ruta_dataset = '/home/david/vision_computador/entrega3/yolo/data/data.yaml'

# Función para evaluar un modelo y obtener mAP50
def evaluar_modelo(modelo_path, dataset_path, nombre_evaluacion, epocas):
    try:
        modelo = YOLO(modelo_path)
        # resultados = modelo.val(data=dataset_path, split='test', project='resultados_test', name=nombre_evaluacion)
        resultados = modelo.train(data=dataset_path, epochs=epocas, project='resultados_20_epoc', name=nombre_evaluacion, imgsz=500, batch=8)
        print(f"Modelo {modelo_path} evaluado correctamente")
        return resultados
    except Exception as e:
        print(f"Error al evaluar el modelo {modelo_path}: {e}")
        return None
    finally:
        # Liberar memoria
        del modelo
        gc.collect()

# %%
# Entrenar modelo 0, yolo5nu.pt
# tiempo de entrenamiento: 20 epochs completed in 0.634 hours.
epocas = 20
nombre_evaluacion = str(epocas)+'epocas'+'_'+modelos[0]
resultados = evaluar_modelo(modelos[0], ruta_dataset, nombre_evaluacion, epocas)
# Out:
# Ultralytics 8.3.53 🚀 Python-3.9.20 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# ...

# %%
# Entrenar modelo 1
# tiempo de entrenamiento: 20 epochs completed in 0.589 hours.

epocas = 20
nombre_evaluacion = str(epocas)+'epocas'+'_'+modelos[1]
resultados = evaluar_modelo(modelos[1], ruta_dataset, nombre_evaluacion, epocas)
# Out:
# Ultralytics 8.3.53 🚀 Python-3.9.20 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# ...

# %%
# Entrenar modelo 2
# tiempo de entrenamiento: 20 epochs completed in 0.830 hours.

epocas = 20
nombre_evaluacion = str(epocas)+'epocas'+'_'+modelos[2]
resultados = evaluar_modelo(modelos[2], ruta_dataset, nombre_evaluacion, epocas)
# Out:
# ...
# 100%|██████████| 4.74M/4.74M [00:00<00:00, 12.8MB/s]
# Ultralytics 8.3.53 🚀 Python-3.9.20 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# ...

# %%
# Entrenar modelo 3
# tiempo de entrenamiento: 20 epochs completed in 0.787 hours.

epocas = 20
nombre_evaluacion = str(epocas)+'epocas'+'_'+modelos[3]
resultados = evaluar_modelo(modelos[3], ruta_dataset, nombre_evaluacion, epocas)
# Out:
# ...
# 100%|██████████| 5.59M/5.59M [00:00<00:00, 12.7MB/s]
# Ultralytics 8.3.53 🚀 Python-3.9.20 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# ...

# %%
# Entrenar modelo 4
# tiempo de entrenamiento: 20 epochs completed in 0.635 hours.

epocas = 20
nombre_evaluacion = str(epocas)+'epocas'+'_'+modelos[4]
resultados = evaluar_modelo(modelos[4], ruta_dataset, nombre_evaluacion, epocas)
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 9.54MB/s]
# Ultralytics 8.3.53 🚀 Python-3.9.20 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# ...

# %%
# Tiempos de entrenamiento
# yolo5 tiempo de entrenamiento: 20 epochs completed in 0.634 hours.
# yolo8 tiempo de entrenamiento: 20 epochs completed in 0.589 hours.
# yolo9 tiempo de entrenamiento: 20 epochs completed in 0.830 hours.
# yolo10 tiempo de entrenamiento: 20 epochs completed in 0.787 hours.
# yolo11 tiempo de entrenamiento: 20 epochs completed in 0.635 hours.

# %%
# Recorremos los directoriso de ntro de resultados _1_epoc
from pathlib import Path
import pandas as pd

# Ruta a la carpeta principal
ruta_principal = Path('./resultados_1_epoc/')

resultados = {}

# Recorrer los subdirectorios
for subdirectorio in ruta_principal.iterdir():
    if subdirectorio.is_dir():
        res_csv = subdirectorio / 'results.csv'
        if res_csv.exists():
            name = subdirectorio.name
            name = name.split('_')[1]
            print(f"Procesando {name}")
            resultados[name] = pd.read_csv(res_csv)
# Out:
# Procesando yolo11n.pt
# Procesando yolov10n.pt
# Procesando yolov5nu.pt
# Procesando yolov8n.pt
# Procesando yolov9t.pt

# %%
# para todos los capos de resultados nos quedamos con el valor más alto y el más bajo
maximos = {}
minimos = {}

for key in resultados.keys():
    maximos[key] = {}
    minimos[key] = {}
    for col in resultados[key].columns:
        if col != 'epoch':
            maximos[key][col] = resultados[key][col].max()
            minimos[key][col] = resultados[key][col].min()

# %%
import matplotlib.pyplot as plt

metricas_altas = ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
colores = ['skyblue', 'lightgreen', 'salmon', 'orange']

fig, axs = plt.subplots(2, 2, figsize=(15, 10))

for i, metrica in enumerate(metricas_altas):
    max_precisiones = {modelo: maximos[modelo][metrica] for modelo in maximos}

    # Graficar los máximos de precisión
    modelos = list(max_precisiones.keys())
    precisiones = list(max_precisiones.values())

    ax = axs[i // 2, i % 2]
    ax.bar(modelos, precisiones, color=colores[i])
    ax.set_xlabel('Modelos')
    ax.set_ylabel(f'Máxima {metrica.split("/")[1]}')
    ax.set_title(f'Máxima {metrica.split("/")[1]} de Cada Modelo')
    ax.set_xticks(range(len(modelos)))
    ax.set_xticklabels(modelos, rotation=45)

    # Ajustar la escala del eje y para resaltar las diferencias
    ax.set_ylim(min(precisiones) - 0.01, max(precisiones) + 0.01)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

metricas_bajas = ['train/box_loss', 'val/box_loss', 'train/cls_loss', 'val/cls_loss', 'train/dfl_loss', 'val/dfl_loss']
colores = ['skyblue', 'lightgreen', 'salmon', 'orange', 'purple', 'brown']

fig, axs = plt.subplots(3, 2, figsize=(15, 15))

for i, metrica in enumerate(metricas_bajas):
    min_valores = {modelo: minimos[modelo][metrica] for modelo in minimos}

    # Graficar los mínimos de las métricas
    modelos = list(min_valores.keys())
    valores = list(min_valores.values())

    ax = axs[i // 2, i % 2]
    ax.bar(modelos, valores, color=colores[i])
    ax.set_xlabel('Modelos')
    ax.set_ylabel(f'Mínima {metrica}')
    ax.set_title(f'Mínima {metrica} de Cada Modelo')
    ax.set_xticks(range(len(modelos)))
    ax.set_xticklabels(modelos, rotation=45)

    # Ajustar la escala del eje y para resaltar las diferencias
    ax.set_ylim(min(valores) - 0.01, max(valores) + 0.01)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Con las gráficas viastas hasta el momento parece que la mejor opción el yolo pero no hemos tenido en cuenta el tiempo de entrenamiento

# %%
# Comparación de tiempo de entrenamiento

# Extraer los tiempos de entrenamiento
tiempos = {modelo: maximos[modelo]['time'] for modelo in maximos}

# Graficar los tiempos de entrenamiento
modelos = list(tiempos.keys())
tiempo = list(tiempos.values())

fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(modelos, tiempo, color='skyblue')
ax.set_xlabel('Modelos')
ax.set_ylabel('Tiempo de Entrenamiento (segundos)')
ax.set_title('Tiempo de Entrenamiento de Cada Modelo')
ax.set_xticks(range(len(modelos)))
ax.set_xticklabels(modelos, rotation=45)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

metricas_altas = ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
colores = ['skyblue', 'lightgreen', 'salmon', 'orange']

fig, axs = plt.subplots(2, 2, figsize=(15, 10))

for i, metrica in enumerate(metricas_altas):
    max_precisiones = {modelo: maximos[modelo][metrica] / maximos[modelo]['time'] for modelo in maximos}

    # Graficar los máximos de precisión divididos por tiempo
    modelos = list(max_precisiones.keys())
    precisiones = list(max_precisiones.values())

    ax = axs[i // 2, i % 2]
    ax.bar(modelos, precisiones, color=colores[i])
    ax.set_xlabel('Modelos')
    ax.set_ylabel(f'Máxima {metrica.split("/")[1]} / Tiempo')
    ax.set_title(f'Máxima {metrica.split("/")[1]} / Tiempo de Cada Modelo')
    ax.set_xticks(range(len(modelos)))
    ax.set_xticklabels(modelos, rotation=45)

    # Ajustar la escala del eje y para resaltar las diferencias
    ax.set_ylim(min(precisiones) - 0.00001, max(precisiones) + 0.00001)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

metricas_bajas = ['train/box_loss', 'val/box_loss', 'train/cls_loss', 'val/cls_loss', 'train/dfl_loss', 'val/dfl_loss']
colores = ['skyblue', 'lightgreen', 'salmon', 'orange', 'purple', 'brown']

fig, axs = plt.subplots(3, 2, figsize=(15, 15))

for i, metrica in enumerate(metricas_bajas):
    min_valores = {modelo: minimos[modelo][metrica] / maximos[modelo]['time'] for modelo in minimos}

    # Graficar los mínimos de las métricas divididos por tiempo
    modelos = list(min_valores.keys())
    valores = list(min_valores.values())

    ax = axs[i // 2, i % 2]
    ax.bar(modelos, valores, color=colores[i])
    ax.set_xlabel('Modelos')
    ax.set_ylabel(f'Mínima {metrica} / Tiempo')
    ax.set_title(f'Mínima {metrica} / Tiempo de Cada Modelo')
    ax.set_xticks(range(len(modelos)))
    ax.set_xticklabels(modelos, rotation=45)

    # Ajustar la escala del eje y para resaltar las diferencias
    ax.set_ylim(min(valores) - 0.00001, max(valores) + 0.00001)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Teniendo en cuenta todos los resultados, el modelos que nos ofrece mejor rendimiento en relación al tiempo de entrenamiento es yolo8, pero el que consigue mejores resultados por época de entrenamiento es yolo9
